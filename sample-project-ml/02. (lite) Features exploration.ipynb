# %% [markdown]
# # Stage 2: Features exploration
#
# In this stage of the project, we are going to analysis each feature separately and understand it's relation to the 'SalePrice' value.

# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline

import pandas as pd
import seaborn as sns

# This module is not included into the sample project
from vizualization import *

# Set seaborn styles
sns.set()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dataset = pd.read_csv('data/house_prices.csv')

# %% [markdown]
# # Features overview

# %%
figsize(15, 6)

# %% [markdown]
# ## MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES

# %%
plot_distribution_agg('MSSubClass', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                      mean            std  len  median
# MSSubClass
# 20          185224.811567   78782.189967  536  159250
# 30           95829.724638   24857.110083   69   99900
# 40          156125.000000   75747.799748    4  142500
# 45          108591.666667   20231.723889   12  107500
# 50          143302.972222   54851.983707  144  132000
# 60          239948.501672   86579.909966  299  215200
# 70          166772.416667   58206.545762   60  156000
# 75          192437.500000  100556.762577   16  163500
# 80          169736.551724   38197.808771   58  166500
# 85          147810.000000   19629.942220   20  140750
# 90          133541.076923   27833.249197   52  135980
# 120         200779.080460   58221.490909   87  192000
# 160         138647.380952   34587.542266   63  146000
# 180         102300.000000   29474.282575   10   88500
# 190         129613.333333   35439.097670   30  128250

# %% [markdown]
# ## MSZoning: Identifies the general zoning classification of the sale.

# %% [markdown]
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential (http://www.cityofames.org/home/showdocument?id=659)
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
#        RP	Residential Low Density Park
#        RM	Residential Medium Density

# %%
plot_distribution_agg('MSZoning', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                    mean           std   len  median
# MSZoning
# C (all)    74528.000000  33791.092031    10   74700
# FV        214014.061538  52369.662067    65  205950
# RH        131558.375000  35714.118435    16  136500
# RL        191004.994787  80766.341319  1151  174000
# RM        126316.830275  48521.689833   218  120500

# %% [markdown]
# ## LotFrontage: Linear feet of street connected to property

# %%
figsize(10, 10)
plot_describe_numerical('LotFrontage', dataset, 'SalePrice')
# Out:
# LotFrontage
# Missing values 259 (17.74%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 12 1.00%
#             mean  median      stdev
# Value  70.049958    69.0  24.284752

# %% [markdown]
# ## LotArea: Lot size in square feet

# %%
plot_describe_numerical('LotArea', dataset, 'SalePrice')
# Out:
# LotArea
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 13 0.89%
#                mean  median        stdev
# Value  10516.828082  9478.5  9981.264932

# %% [markdown]
# ## Street: Type of road access to property

# %% [markdown]
# Street: Type of road access to property
#
#        Grvl	Gravel
#        Pave	Paved

# %%
plot_distribution_agg('Street', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                  mean           std   len  median
# Street
# Grvl    130190.500000  65446.253991     6  114250
# Pave    181130.538514  79446.597317  1454  163000

# %% [markdown]
# # Alley: Type of alley access to property

# %% [markdown]
#
# Alley: Type of alley access to property
#
# An alley or alleyway is a narrow lane, path, or passageway, often reserved for pedestrians, which usually runs between, behind, or within buildings in the older parts of towns and cities. It is also a rear access or service road (back lane), or a path or walk in a park or garden.[1] https://en.wikipedia.org/wiki/Alley
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access

# %%
plot_distribution_agg('Alley', dataset, 'SalePrice')
# Out:
# Missing values 1369 (93.77%)
#                 mean           std   len  median
# Alley
# !NA!   183452.131483  80667.145180  1369  165000
# Grvl   122219.080000  34780.780734    50  119500
# Pave   168000.585366  38370.375243    41  172500

# %% [markdown]
# ## LotShape: General shape of property

# %% [markdown]
# LotShape: General shape of property
#
#        Reg	Regular
#        IR1	Slightly irregular
#        IR2	Moderately Irregular
#        IR3	Irregular

# %%
plot_distribution_agg('LotShape', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                    mean           std  len  median
# LotShape
# IR1       206101.665289  85858.489559  484  189000
# IR2       239833.365854  99669.427362   41  221000
# IR3       216036.500000  82540.334855   10  203570
# Reg       164754.818378  69673.427215  925  146000

# %% [markdown]
# ## LandContour: Flatness of the property

# %% [markdown]
# LandContour: Flatness of the property
#
#        Lvl	Near Flat/Level
#        Bnk	Banked - Quick and significant rise from street grade to building
#        HLS	Hillside - Significant slope from side to side
#        Low	Depression

# %%
plot_distribution_agg('LandContour', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                       mean            std   len  median
# LandContour
# Bnk          143104.079365   49361.244074    63  139400
# HLS          231533.940000  101790.139741    50  222250
# Low          203661.111111   83935.353620    36  190000
# Lvl          180183.746758   78463.567918  1311  162900

# %% [markdown]
# ## Utilities: Type of utilities available
#
#        AllPub	All public Utilities (E,G,W,& S)
#        NoSewr	Electricity, Gas, and Water (Septic Tank)
#        NoSeWa	Electricity and Gas Only
#        ELO	Electricity only

# %%
plot_distribution_agg('Utilities', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                    mean           std   len  median
# Utilities
# AllPub     180950.95682  79461.599814  1459  163000
# NoSeWa     137500.00000           NaN     1  137500

# %% [markdown]
# ## LotConfig: Lot configuration
#
# - Inside	Inside lot
# - Corner	Corner lot
# - CulDSac	Cul-de-sac
# - FR2	Frontage on 2 sides of property
# - FR3	Frontage on 3 sides of property

# %%
plot_distribution_agg('LotConfig', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                     mean           std   len    median
# LotConfig
# Corner     181623.425856  84466.041222   263  160000.0
# CulDSac    223854.617021  93117.546586    94  199262.0
# FR2        177934.574468  62788.926829    47  165000.0
# FR3        208475.000000  78379.222374     4  195450.0
# Inside     176938.047529  76426.805787  1052  159697.5

# %% [markdown]
# ## LandSlope: Slope of property
#
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope

# %%
plot_distribution_agg('LandSlope', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                     mean           std   len  median
# LandSlope
# Gtl        179956.799566  78669.369151  1382  161875
# Mod        196734.138462  92375.358116    65  186700
# Sev        204379.230769  86729.922409    13  185000

# %% [markdown]
# ## Neighborhood: Physical locations within Ames city limits
#
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker

# %%
plot_distribution_agg('Neighborhood', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                        mean            std  len  median
# Neighborhood
# Blmngtn       194870.882353   30393.229219   17  191000
# Blueste       137500.000000   19091.883092    2  137500
# BrDale        104493.750000   14330.176493   16  106000
# BrkSide       124834.051724   40348.689270   58  124300
# ClearCr       212565.428571   50231.538993   28  200250
# CollgCr       197965.773333   51403.666438  150  197200
# Crawfor       210624.725490   68866.395472   51  200624
# Edwards       128219.700000   43208.616459  100  121750
# Gilbert       192854.506329   35986.779085   79  181000
# IDOTRR        100123.783784   33376.710117   37  103000
# MeadowV        98576.470588   23491.049610   17   88000
# Mitchel       156270.122449   36486.625334   49  153500
# NAmes         145847.080000   33075.345450  225  140000
# NPkVill       142694.444444    9377.314529    9  146000
# NWAmes        189050.068493   37172.218106   73  182900
# ...

# %% [markdown]
# ## Condition1: Proximity to various conditions
#
#        Artery	Adjacent to arterial street (a high-capacity urban road.)
#        Feedr	Adjacent to feeder street (a minor road used to bring traffic to a major road.)
#        Norm	Normal
#        RRNn	Within 200 feet of North-South Railroad
#        RRAn	Adjacent (near) to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200 feet of East-West Railroad
#        RRAe	Adjacent (near) to East-West Railroad

# %%
plot_distribution_agg('Condition1', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                      mean           std   len  median
# Condition1
# Artery      135091.666667  66226.660548    48  119550
# Feedr       142475.481481  42157.290117    81  140000
# Norm        184495.492063  81256.980125  1260  166500
# PosA        225875.000000  52348.932313     8  212500
# PosN        215184.210526  65256.536609    19  200000
# RRAe        138400.000000  24030.813553    11  142500
# RRAn        184396.615385  66177.922070    26  171495
# RRNe        190750.000000   5303.300859     2  190750
# RRNn        212400.000000  93823.238060     5  214000

# %% [markdown]
# ## Condition2: Proximity to various conditions (if more than one is present)
#
#        Artery	Adjacent to arterial street (a high-capacity urban road.)
#        Feedr	Adjacent to feeder street (a minor road used to bring traffic to a major road.)
#        Norm	Normal
#        RRNn	Within 200 feet of North-South Railroad
#        RRAn	Adjacent (near) to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200 feet of East-West Railroad
#        RRAe	Adjacent (near) to East-West Railroad

# %%
plot_distribution_agg('Condition2', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                      mean            std   len  median
# Condition2
# Artery      106500.000000   16263.455967     2  106500
# Feedr       121166.666667   33544.994659     6  127500
# Norm        181169.405536   79337.735547  1445  163500
# PosA        325000.000000            NaN     1  325000
# PosN        284875.000000  141598.132933     2  284875
# RRAe        190000.000000            NaN     1  190000
# RRAn        136905.000000            NaN     1  136905
# RRNn         96750.000000   39951.533137     2   96750

# %% [markdown]
# ## BldgType: Type of dwelling (building)
#
#        1Fam	Single-family Detached
#        2FmCon	Two-family Conversion; originally built as one-family dwelling
#        Duplx	Duplex
#        TwnhsE	Townhouse End Unit
#        TwnhsI	Townhouse Inside Unit

# %%
plot_distribution_agg('BldgType', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                    mean           std   len  median
# BldgType
# 1Fam      185763.807377  82648.502922  1220  167900
# 2fmCon    128432.258065  35458.545158    31  127500
# Duplex    133541.076923  27833.249197    52  135980
# Twnhs     135911.627907  41013.222080    43  137500
# TwnhsE    181959.342105  60626.108918   114  172200

# %% [markdown]
# ## HouseStyle: Style of dwelling
#
#        1Story	One story
#        1.5Fin	One and one-half story: 2nd level finished
#        1.5Unf	One and one-half story: 2nd level unfinished
#        2Story	Two story
#        2.5Fin	Two and one-half story: 2nd level finished
#        2.5Unf	Two and one-half story: 2nd level unfinished
#        SFoyer	Split Foyer
#        SLvl	Split Level

# %%
plot_distribution_agg('HouseStyle', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                      mean            std  len  median
# HouseStyle
# 1.5Fin      143116.740260   54277.941119  154  132000
# 1.5Unf      110150.000000   19036.473090   14  111250
# 1Story      175985.477961   77055.715011  726  154750
# 2.5Fin      220000.000000  118211.976671    8  194000
# 2.5Unf      157354.545455   63934.128032   11  133900
# 2Story      210051.764045   87339.213570  445  190000
# SFoyer      135074.486486   30480.898192   37  135960
# SLvl        166703.384615   38305.161339   65  164500

# %% [markdown]
# ## OverallQual: Rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor

# %%
plot_distribution_agg('OverallQual', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                       mean            std  len  median
# OverallQual
# 1             50150.000000   15344.217152    2   50150
# 2             51770.333333   14254.200796    3   60000
# 3             87473.750000   24688.567399   20   86250
# 4            108420.655172   29022.003886  116  108000
# 5            133523.347607   27107.330927  397  133000
# 6            161603.034759   36090.182933  374  160000
# 7            207716.423197   44466.259414  319  200141
# 8            274735.535714   63898.902253  168  269750
# 9            367513.023256   81278.174849   43  345000
# 10           438588.388889  159785.491058   18  432390

# %% [markdown]
# ## OverallCond: Rates the overall condition of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor

# %%
plot_distribution_agg('OverallCond', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                       mean            std  len  median
# OverallCond
# 1             61000.000000            NaN    1   61000
# 2            141986.400000  141342.813488    5   85000
# 3            101929.400000   44852.490403   25   89500
# 4            120438.438596   38922.525907   57  115000
# 5            203146.914738   85117.319416  821  185000
# 6            153961.591270   60737.969824  252  142750
# 7            158145.487805   53468.189431  205  145000
# 8            155651.736111   52375.144681   72  142500
# 9            216004.545455   96485.974689   22  176200

# %% [markdown]
# ## YearBuilt: Original construction date

# %%
plot_describe_numerical('YearBuilt', dataset, 'SalePrice')
# Out:
# YearBuilt
# Missing values 0 (0.00%)
# Outliers < -3sigma: 6 0.41%
# Outliers > +3sigma: 0 0.00%
#               mean  median      stdev
# Value  1971.267808  1973.0  30.202904

# %% [markdown]
# ## YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)

# %%
plot_describe_numerical('YearRemodAdd', dataset, 'SalePrice')
# Out:
# YearRemodAdd
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 0 0.00%
#               mean  median      stdev
# Value  1984.865753  1994.0  20.645407

# %% [markdown]
# ## RoofStyle: Type of roof
#
#        Flat	    Flat
#        Gable	Gable
#        Gambrel	Gabrel (Barn)
#        Hip	    Hip
#        Mansard	Mansard
#        Shed	    Shed

# %%
plot_distribution_agg('RoofStyle', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                     mean            std   len  median
# RoofStyle
# Flat       194690.000000   62522.963515    13  185000
# Gable      171483.956179   66331.237296  1141  160000
# Gambrel    148909.090909   67013.527807    11  139000
# Hip        218876.933566  111549.603563   286  176500
# Mansard    180568.428571   58057.624627     7  175000
# Shed       225000.000000   49497.474683     2  225000

# %% [markdown]
# ## RoofMatl: Roof material
#
#        ClyTile	Clay or Tile
#        CompShg	Standard (Composite) Shingle
#        Membran	Membrane
#        Metal	Metal
#        Roll	Roll
#        Tar&Grv	Gravel & Tar
#        WdShake	Wood Shakes
#        WdShngl	Wood Shingles

# %%
plot_distribution_agg('RoofMatl', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                    mean            std   len  median
# RoofMatl
# ClyTile   160000.000000            NaN     1  160000
# CompShg   179803.679219   77722.388636  1434  162000
# Membran   241500.000000            NaN     1  241500
# Metal     180000.000000            NaN     1  180000
# Roll      137000.000000            NaN     1  137000
# Tar&Grv   185406.363636   65430.141720    11  167000
# WdShake   241400.000000   36218.779659     5  242000
# WdShngl   390250.000000  206969.019421     6  332500

# %% [markdown]
# ## Exterior1st: Exterior covering on house
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles

# %%
plot_distribution_agg('Exterior1st', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                       mean            std  len    median
# Exterior1st
# AsbShng      107385.550000   33756.480660   20  108000.0
# AsphShn      100000.000000            NaN    1  100000.0
# BrkComm       71000.000000   15556.349186    2   71000.0
# BrkFace      194573.000000   82841.914370   50  165750.0
# CBlock       105000.000000            NaN    1  105000.0
# CemntBd      231690.655738  120575.621318   61  236500.0
# HdBoard      163077.450450   66305.714164  222  149900.0
# ImStucc      262000.000000            NaN    1  262000.0
# MetalSd      149422.177273   54776.408990  220  139000.0
# Plywood      175942.379630   49497.383293  108  167450.0
# Stone        258500.000000   40305.086528    2  258500.0
# Stucco       162990.000000   83307.246529   25  144000.0
# VinylSd      213732.900971   80646.975785  515  200000.0
# Wd Sdng      149841.645631   71130.448152  206  138943.5
# WdShing      150655.076923   72507.530741   26  128700.0

# %% [markdown]
# ## Exterior2nd: Exterior covering on house (if more than one material)
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles

# %%
plot_distribution_agg('Exterior2nd', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                       mean            std  len    median
# Exterior2nd
# AsbShng      114060.550000   42315.043608   20  111000.0
# AsphShn      138000.000000   37509.998667    3  139000.0
# Brk Cmn      126714.285714   38693.084161    7  147000.0
# BrkFace      195818.000000   95097.551756   25  160000.0
# CBlock       105000.000000            NaN    1  105000.0
# CmentBd      230093.833333  116140.396221   60  238750.0
# HdBoard      167661.565217   70061.078357  207  155000.0
# ImStucc      252070.000000  193176.672447   10  187600.0
# MetalSd      149803.172897   55078.595310  214  138750.0
# Other        319000.000000            NaN    1  319000.0
# Plywood      168112.387324   46955.744372  142  160750.0
# Stone        158224.800000   63533.067573    5  177000.0
# Stucco       155905.153846   74862.492410   26  142000.0
# VinylSd      214432.460317   80708.309670  504  200070.5
# Wd Sdng      148386.065990   59892.856640  197  138000.0
# ...

# %% [markdown]
# ## MasVnrType: Masonry veneer type
#
#        BrkCmn	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        None	None
#        Stone	Stone

# %%
plot_distribution_agg('MasVnrType', dataset, 'SalePrice')
# Out:
# Missing values 8 (0.55%)
#                      mean           std  len  median
# MasVnrType
# !NA!        236484.250000  93964.474968    8  203287
# BrkCmn      146318.066667  46187.583632   15  139000
# BrkFace     204691.871910  81214.293554  445  181000
# None        156221.891204  60708.262798  864  143000
# Stone       265583.625000  99940.156577  128  246839

# %% [markdown]
# ##  MasVnrArea: Masonry veneer area in square feet

# %%
plot_describe_numerical('MasVnrArea', dataset, 'SalePrice')
# Out:
# MasVnrArea
# Missing values 8 (0.55%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 32 2.20%
#              mean  median       stdev
# Value  103.685262     0.0  181.066207

# %% [markdown]
# ## ExterQual: Evaluates the quality of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor

# %%
plot_distribution_agg('ExterQual', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                     mean            std  len    median
# ExterQual
# Ex         367360.961538  116401.264200   52  364606.5
# Fa          87985.214286   39826.918794   14   82250.0
# Gd         231633.510246   71188.873899  488  220000.0
# TA         144341.313466   42471.815703  906  139450.0

# %% [markdown]
# ## ExterCond: Evaluates the present condition of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor

# %%
plot_distribution_agg('ExterCond', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                     mean            std   len  median
# ExterCond
# Ex         201333.333333  109235.220205     3  161000
# Fa         102595.142857   40094.383940    28   95750
# Gd         168897.568493   72608.303632   146  151250
# Po          76500.000000            NaN     1   76500
# TA         184034.896256   79806.257233  1282  167370

# %% [markdown]
# ## Foundation: Type of foundation
#
#        BrkTil	Brick & Tile
#        CBlock	Cinder Block
#        PConc	Poured Contrete
#        Slab	    Slab
#        Stone	Stone
#        Wood	    Wood

# %%
plot_distribution_agg('Foundation', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                      mean           std  len  median
# Foundation
# BrkTil      132291.075342  54592.393032  146  125250
# CBlock      149805.714511  48295.041759  634  141500
# PConc       225230.442040  86865.977283  647  205000
# Slab        107365.625000  34213.980939   24  104150
# Stone       165959.166667  78557.704413    6  126500
# Wood        185666.666667  56695.090910    3  164000

# %% [markdown]
# ## BsmtQual: Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement

# %%
plot_distribution_agg('BsmtQual', dataset, 'SalePrice')
# Out:
# Missing values 37 (2.53%)
#                    mean            std  len  median
# BsmtQual
# !NA!      105652.891892   29278.694797   37  101800
# Ex        327041.041322  113563.237392  121  318000
# Fa        115692.028571   34469.667278   35  112000
# Gd        202688.478964   58092.364284  618  192070
# TA        140759.818182   43483.265311  649  135500

# %% [markdown]
# ## BsmtCond: Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement

# %%
plot_distribution_agg('BsmtCond', dataset, 'SalePrice')
# Out:
# Missing values 37 (2.53%)
#                    mean           std   len  median
# BsmtCond
# !NA!      105652.891892  29278.694797    37  101800
# Fa        121809.533333  43467.796975    45  118500
# Gd        213599.907692  72663.155026    65  193879
# Po         64000.000000   4242.640687     2   64000
# TA        183632.620900  79515.388449  1311  165000

# %% [markdown]
# ## BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement

# %%
plot_distribution_agg('BsmtExposure', dataset, 'SalePrice')
# Out:
# Missing values 38 (2.60%)
#                        mean            std  len  median
# BsmtExposure
# !NA!          107938.342105   32133.440664   38  104025
# Av            206643.420814   88655.504849  221  185850
# Gd            257689.805970  118923.672583  134  226975
# Mn            192789.657895   77335.442652  114  182450
# No            165652.295908   60695.724915  953  154000

# %% [markdown]
# ## BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement

# %%
plot_distribution_agg('BsmtFinType1', dataset, 'SalePrice')
# Out:
# Missing values 37 (2.53%)
#                        mean           std  len  median
# BsmtFinType1
# !NA!          105652.891892  29278.694797   37  101800
# ALQ           161573.068182  50821.277231  220  149250
# BLQ           149493.655405  47327.292126  148  139100
# GLQ           235413.720096  93215.613258  418  213750
# LwQ           151852.702703  50796.987083   74  139000
# Rec           146889.248120  45190.118879  133  142000
# Unf           170670.576744  72577.080129  430  161750

# %% [markdown]
# ## BsmtFinSF1: Type 1 finished square feet

# %%
plot_describe_numerical('BsmtFinSF1', dataset, 'SalePrice')
# Out:
# BsmtFinSF1
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 6 0.41%
#              mean  median       stdev
# Value  443.639726   383.5  456.098091

# %% [markdown]
# ## BsmtFinType2: Rating of basement finished area (if multiple types)
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement

# %%
plot_distribution_agg('BsmtFinType2', dataset, 'SalePrice')
# Out:
# Missing values 38 (2.60%)
#                        mean            std   len  median
# BsmtFinType2
# !NA!          110346.236842   40879.307312    38  104025
# ALQ           209942.105263  104764.743411    19  174900
# BLQ           151101.000000   41611.305388    33  143000
# GLQ           180982.142857   64573.040359    14  203125
# LwQ           164364.130435   43255.035241    46  154000
# Rec           164917.129630   59183.277020    54  148750
# Unf           184694.690287   81275.313909  1256  167000

# %% [markdown]
# ## BsmtFinSF2: Type 2 finished square feet

# %%
plot_describe_numerical('BsmtFinSF2', dataset, 'SalePrice')
# Out:
# BsmtFinSF2
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 50 3.42%
#             mean  median       stdev
# Value  46.549315     0.0  161.319273

# %% [markdown]
# ## TotalBsmtSF: Total square feet of basement area

# %%
plot_describe_numerical('TotalBsmtSF', dataset, 'SalePrice')
# Out:
# TotalBsmtSF
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 10 0.68%
#               mean  median       stdev
# Value  1057.429452   991.5  438.705324

# %% [markdown]
# ## Heating: Type of heating
#
#        Floor	Floor Furnace
#        GasA	Gas forced warm air furnace
#        GasW	Gas hot water or steam heat
#        Grav	Gravity furnace
#        OthW	Hot water or steam heat other than gas
#        Wall	Wall furnace

# %%
plot_distribution_agg('Heating', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                   mean           std   len  median
# Heating
# Floor     72500.000000           NaN     1   72500
# GasA     182021.195378  79262.873587  1428  164500
# GasW     166632.166667  78547.575324    18  134950
# Grav      75271.428571  28066.570524     7   79000
# OthW     125750.000000   5303.300859     2  125750
# Wall      92100.000000   4509.988914     4   91450

# %% [markdown]
# ## HeatingQC: Heating quality and condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor

# %%
plot_distribution_agg('HeatingQC', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                     mean           std  len  median
# HeatingQC
# Ex         214914.429150  87469.704503  741  194700
# Fa         123919.489796  50306.618996   49  123500
# Gd         156858.871369  52923.920003  241  152000
# Po          87000.000000           NaN    1   87000
# TA         142362.876168  47226.485663  428  135000

# %% [markdown]
# ## CentralAir: Central air conditioning
#
#        N	No
#        Y	Yes

# %%
plot_distribution_agg('CentralAir', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                      mean           std   len  median
# CentralAir
# N           105264.073684  40671.273961    95   98000
# Y           186186.709890  78805.206820  1365  168000

# %% [markdown]
# ## Electrical: Electrical system
#
#        SBrkr	Standard Circuit Breakers & Romex
#        FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
#        FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
#        FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
#        Mix	Mixed

# %%
plot_distribution_agg('Electrical', dataset, 'SalePrice')
# Out:
# Missing values 1 (0.07%)
#                      mean           std   len  median
# Electrical
# !NA!        167500.000000           NaN     1  167500
# FuseA       122196.893617  37511.376615    94  121250
# FuseF       107675.444444  30636.507376    27  115000
# FuseP        97333.333333  34645.827070     3   82000
# Mix          67000.000000           NaN     1   67000
# SBrkr       186825.113193  79856.458326  1334  170000

# %% [markdown]
# ## 1stFlrSF: First Floor square feet

# %%
plot_describe_numerical('1stFlrSF', dataset, 'SalePrice')
# Out:
# 1stFlrSF
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 12 0.82%
#               mean  median       stdev
# Value  1162.626712  1087.0  386.587738

# %% [markdown]
# ## 2ndFlrSF: Second floor square feet

# %%
plot_describe_numerical('2ndFlrSF', dataset, 'SalePrice')
# Out:
# 2ndFlrSF
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 4 0.27%
#              mean  median       stdev
# Value  346.992466     0.0  436.528436

# %% [markdown]
# ## LowQualFinSF: Low quality finished square feet (all floors)

# %%
plot_describe_numerical('LowQualFinSF', dataset, 'SalePrice')
# Out:
# LowQualFinSF
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 20 1.37%
#            mean  median      stdev
# Value  5.844521     0.0  48.623081

# %% [markdown]
# ## GrLivArea: Above grade (ground) living area square feet

# %%
plot_describe_numerical('GrLivArea', dataset, 'SalePrice')
# Out:
# GrLivArea
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 16 1.10%
#               mean  median       stdev
# Value  1515.463699  1464.0  525.480383

# %% [markdown]
# ## BsmtFullBath: Basement full bathrooms

# %%
plot_distribution_agg('BsmtFullBath', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                        mean           std  len  median
# BsmtFullBath
# 0             165521.640187  68137.819610  856  154150
# 1             202522.918367  88895.866415  588  178800
# 2             213063.066667  87308.196346   15  188000
# 3             179000.000000           NaN    1  179000

# %% [markdown]
# ## BsmtHalfBath: Basement half bathrooms

# %%
plot_distribution_agg('BsmtHalfBath', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                        mean           std   len    median
# BsmtHalfBath
# 0             181230.330189  79303.224623  1378  163250.0
# 1             176098.125000  82901.003355    80  159000.0
# 2             160850.500000  47164.729412     2  160850.5

# %% [markdown]
# ## BedroomAbvGr: Bedrooms above grade (does NOT include basement bedrooms)

# %%
plot_distribution_agg('BedroomAbvGr', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                        mean            std  len  median
# BedroomAbvGr
# 0             221493.166667  106675.888935    6  202500
# 1             173162.420000  102975.067584   50  145250
# 2             158197.659218   78197.106241  358  137250
# 3             181056.870647   63793.924903  804  169945
# 4             220421.253521  109510.516383  213  193500
# 5             180819.047619   68472.480743   21  161500
# 6             143779.000000   26455.384839    7  141000
# 8             200000.000000            NaN    1  200000

# %% [markdown]
# ## KitchenAbvGr: Kitchens above grade

# %%
plot_distribution_agg('KitchenAbvGr', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                        mean           std   len  median
# KitchenAbvGr
# 0             127500.000000           NaN     1  127500
# 1             183388.790230  80265.344315  1392  165550
# 2             131096.153846  31483.474549    65  133900
# 3             109500.000000   4949.747468     2  109500

# %% [markdown]
# ## KitchenQual: Kitchen quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor

# %%
plot_distribution_agg('KitchenQual', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                       mean            std  len  median
# KitchenQual
# Ex           328554.670000  120862.942573  100  316750
# Fa           105565.205128   36004.254037   39  115000
# Gd           212116.023891   64020.176702  586  201400
# TA           139962.511565   38896.280336  735  137000

# %% [markdown]
# ## TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)

# %%
plot_distribution_agg('TotRmsAbvGrd', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                        mean            std  len    median
# TotRmsAbvGrd
# 2              39300.000000            NaN    1   39300.0
# 3             111217.647059   33108.103904   17  100000.0
# 4             122844.628866   41661.805370   97  120500.0
# 5             141550.749091   49656.905700  275  130250.0
# 6             161303.296020   48707.372941  402  155000.0
# 7             196666.784195   64404.686026  329  184100.0
# 8             213427.529412   73985.715639  187  200000.0
# 9             252988.173333   83131.922273   75  252000.0
# 10            296279.170213  155027.992122   47  285000.0
# 11            318022.000000  148216.975202   18  311738.5
# 12            280971.454545  165510.918593   11  200000.0
# 14            200000.000000            NaN    1  200000.0

# %% [markdown]
# ## Functional: Home functionality (Assume typical unless deductions are warranted)
#
#        Typ	Typical Functionality
#        Min1	Minor Deductions 1
#        Min2	Minor Deductions 2
#        Mod	Moderate Deductions
#        Maj1	Major Deductions 1
#        Maj2	Major Deductions 2
#        Sev	Severely Damaged
#        Sal	Salvage only

# %%
plot_distribution_agg('Functional', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                      mean            std   len  median
# Functional
# Maj1        153948.142857   64503.775815    14  140750
# Maj2         85800.000000   27086.897201     5   85000
# Min1        146385.483871   38089.572487    31  139000
# Min2        144240.647059   41215.354652    34  140000
# Mod         168393.333333  118938.666467    15  137900
# Sev         129000.000000            NaN     1  129000
# Typ         183429.147059   80017.959658  1360  165500

# %% [markdown]
# ## Fireplaces: Number of fireplaces

# %%
plot_distribution_agg('Fireplaces', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                      mean            std  len  median
# Fireplaces
# 0           141331.482609   44389.786884  690  135000
# 1           211843.909231   79531.825318  650  189975
# 2           240588.539130  117451.800525  115  206900
# 3           252000.000000   93313.986090    5  205000

# %% [markdown]
# ## FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace

# %%
plot_distribution_agg('FireplaceQu', dataset, 'SalePrice')
# Out:
# Missing values 690 (47.26%)
#                       mean            std  len  median
# FireplaceQu
# !NA!         141331.482609   44389.786884  690  135000
# Ex           337712.500000  123611.471764   24  314250
# Fa           167298.484848   34287.717564   33  158000
# Gd           226351.415789   91123.148369  380  206950
# Po           129764.150000   31080.842115   20  131500
# TA           205723.488818   71367.028772  313  187500

# %% [markdown]
# ## GarageType: Garage location
#
#        2Types	More than one type of garage
#        Attchd	Attached to home
#        Basment	Basement Garage
#        BuiltIn	Built-In (Garage part of house - typically has room above garage)
#        CarPort	Car Port
#        Detchd	Detached from home
#        NA	No Garage

# %%
plot_distribution_agg('GarageType', dataset, 'SalePrice')
# Out:
# Missing values 81 (5.55%)
#                      mean            std  len  median
# GarageType
# !NA!        103317.283951   32815.023389   81  100000
# 2Types      151283.333333   34917.068415    6  159000
# Attchd      202892.656322   77146.621778  870  185000
# Basment     160570.684211   63967.283574   19  148000
# BuiltIn     254751.738636  102230.854394   88  227500
# CarPort     109962.111111   24638.183681    9  108000
# Detchd      134091.162791   41391.549953  387  129500

# %% [markdown]
# ## GarageYrBlt: Year garage was built

# %%
plot_describe_numerical('GarageYrBlt', dataset, 'SalePrice')
# Out:
# GarageYrBlt
# Missing values 81 (5.55%)
# Outliers < -3sigma: 1 0.07%
# Outliers > +3sigma: 0 0.00%
#               mean  median      stdev
# Value  1978.506164  1980.0  24.689725

# %% [markdown]
# ## GarageFinish: Interior finish of the garage
#
#        Fin	Finished
#        RFn	Rough Finished
#        Unf	Unfinished
#        NA	No Garage

# %%
plot_distribution_agg('GarageFinish', dataset, 'SalePrice')
# Out:
# Missing values 81 (5.55%)
#                        mean           std  len  median
# GarageFinish
# !NA!          103317.283951  32815.023389   81  100000
# Fin           240052.690341  96960.593232  352  215000
# RFn           202068.869668  63536.222518  422  190000
# Unf           142156.423140  46498.528211  605  135000

# %% [markdown]
# ## GarageCars: Size of garage in car capacity

# %%
plot_distribution_agg('GarageCars', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                      mean            std  len  median
# GarageCars
# 0           103317.283951   32815.023389   81  100000
# 1           128116.688347   30412.386890  369  128000
# 2           183851.663835   51617.144258  824  177750
# 3           309636.121547  106832.925939  181  295000
# 4           192655.800000   52621.839745    5  200000

# %% [markdown]
# ## GarageArea: Size of garage in square feet

# %%
plot_describe_numerical('GarageArea', dataset, 'SalePrice')
# Out:
# GarageArea
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 7 0.48%
#              mean  median       stdev
# Value  472.980137   480.0  213.804841

# %% [markdown]
# ## GarageQual: Garage quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage

# %%
plot_distribution_agg('GarageQual', dataset, 'SalePrice')
# Out:
# Missing values 81 (5.55%)
#                      mean            std   len  median
# GarageQual
# !NA!        103317.283951   32815.023389    81  100000
# Ex          241000.000000  202680.166765     3  127500
# Fa          123573.354167   42971.440985    48  115000
# Gd          215860.714286   74126.739021    14  209115
# Po          100166.666667   35143.752408     3   96500
# TA          187489.836003   78774.948567  1311  170000

# %% [markdown]
# ## GarageCond: Garage condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage

# %%
plot_distribution_agg('GarageCond', dataset, 'SalePrice')
# Out:
# Missing values 81 (5.55%)
#                      mean           std   len  median
# GarageCond
# !NA!        103317.283951  32815.023389    81  100000
# Ex          124000.000000   4949.747468     2  124000
# Fa          114654.028571  36420.903588    35  114504
# Gd          179930.000000  64769.318354     9  148000
# Po          108500.000000  22662.377045     7  108000
# TA          187885.735294  79103.322640  1326  170000

# %% [markdown]
# ## PavedDrive: Paved driveway
#
#        Y	Paved
#        P	Partial Pavement
#        N	Dirt/Gravel

# %%
plot_distribution_agg('PavedDrive', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                      mean           std   len  median
# PavedDrive
# N           115039.122222  44352.523309    90  111000
# P           132330.000000  33503.030228    30  132250
# Y           186433.973881  79665.503047  1340  168500

# %% [markdown]
# ## WoodDeckSF: Wood deck area in square feet

# %%
plot_describe_numerical('WoodDeckSF', dataset, 'SalePrice')
# Out:
# WoodDeckSF
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 22 1.51%
#             mean  median       stdev
# Value  94.244521     0.0  125.338794

# %% [markdown]
# ## OpenPorchSF: Open porch area in square feet

# %%
plot_describe_numerical('OpenPorchSF', dataset, 'SalePrice')
# Out:
# OpenPorchSF
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 27 1.85%
#             mean  median      stdev
# Value  46.660274    25.0  66.256028

# %% [markdown]
# ## EnclosedPorch: Enclosed porch area in square feet

# %%
plot_describe_numerical('EnclosedPorch', dataset, 'SalePrice')
# Out:
# EnclosedPorch
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 51 3.49%
#            mean  median      stdev
# Value  21.95411     0.0  61.119149

# %% [markdown]
# ## 3SsnPorch: Three season porch area in square feet

# %%
plot_describe_numerical('3SsnPorch', dataset, 'SalePrice')
# Out:
# 3SsnPorch
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 23 1.58%
#            mean  median      stdev
# Value  3.409589     0.0  29.317331

# %% [markdown]
# ## ScreenPorch: Screen porch area in square feet

# %%
plot_describe_numerical('ScreenPorch', dataset, 'SalePrice')
# Out:
# ScreenPorch
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 55 3.77%
#             mean  median      stdev
# Value  15.060959     0.0  55.757415

# %% [markdown]
# ## PoolArea: Pool area in square feet

# %%
plot_describe_numerical('PoolArea', dataset, 'SalePrice')
# Out:
# PoolArea
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 7 0.48%
#            mean  median      stdev
# Value  2.758904     0.0  40.177307

# %% [markdown]
# ## PoolQC: Pool quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        NA	No Pool

# %%
plot_distribution_agg('PoolQC', dataset, 'SalePrice')
# Out:
# Missing values 1453 (99.52%)
#                  mean            std   len  median
# PoolQC
# !NA!    180404.663455   78168.872519  1453  162900
# Ex      490000.000000  360624.458405     2  490000
# Fa      215500.000000   48790.367902     2  215500
# Gd      201990.000000   63441.392639     3  171000

# %% [markdown]
# ## Fence: Fence quality
#
#        GdPrv	Good Privacy
#        MnPrv	Minimum Privacy
#        GdWo	Good Wood
#        MnWw	Minimum Wood/Wire
#        NA	No Fence

# %%
plot_distribution_agg('Fence', dataset, 'SalePrice')
# Out:
# Missing values 1179 (80.75%)
#                 mean           std   len  median
# Fence
# !NA!   187596.837998  81656.497075  1179  173000
# GdPrv  178927.457627  56757.237563    59  167500
# GdWo   140379.314815  53592.585059    54  138750
# MnPrv  148751.089172  66096.069463   157  137450
# MnWw   134286.363636  21781.805376    11  130000

# %% [markdown]
# ## MiscFeature: Miscellaneous feature not covered in other categories
#
#        Elev	Elevator
#        Gar2	2nd Garage (if not described in garage section)
#        Othr	Other
#        Shed	Shed (over 100 SF)
#        TenC	Tennis Court
#        NA	None

# %%
plot_distribution_agg('MiscFeature', dataset, 'SalePrice')
# Out:
# Missing values 1406 (96.30%)
#                       mean           std   len  median
# MiscFeature
# !NA!         182046.410384  80084.136570  1406  164250
# Gar2         170750.000000  27223.611076     2  170750
# Othr          94000.000000  55154.328933     2   94000
# Shed         151187.612245  51642.728056    49  144000
# TenC         250000.000000           NaN     1  250000

# %% [markdown]
# ## MiscVal: $Value of miscellaneous feature

# %%
plot_describe_numerical('MiscVal', dataset, 'SalePrice')
# Out:
# MiscVal
# Missing values 0 (0.00%)
# Outliers < -3sigma: 0 0.00%
# Outliers > +3sigma: 8 0.55%
#             mean  median       stdev
# Value  43.489041     0.0  496.123024

# %% [markdown]
# ## MoSold: Month Sold (MM)
# ## YrSold: Year Sold (YYYY)

# %%
plot_distribution_agg('YrSold', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                  mean           std  len  median
# YrSold
# 2006    182549.458599  79426.838855  314  163995
# 2007    186063.151976  85768.171410  329  167000
# 2008    177360.838816  69735.610685  304  164000
# 2009    179432.103550  80879.237311  338  162000
# 2010    177393.674286  80451.280085  175  155000

# %% [markdown]
# ## SaleType: Type of sale
#
#        WD 	Warranty Deed - Conventional
#        CWD	Warranty Deed - Cash
#        VWD	Warranty Deed - VA Loan
#        New	Home just constructed and sold
#        COD	Court Officer Deed/Estate
#        Con	Contract 15% Down payment regular terms
#        ConLw	Contract Low Down payment and low interest
#        ConLI	Contract Low Interest
#        ConLD	Contract Low Down
#        Oth	Other

# %%
plot_distribution_agg('SaleType', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                    mean            std   len  median
# SaleType
# COD       143973.255814   47098.294314    43  139000
# CWD       210600.000000   86421.486526     4  188750
# Con       269600.000000   76933.217793     2  269600
# ConLD     138780.888889   53876.560647     9  140000
# ConLI     200390.000000  145282.519595     5  125000
# ConLw     143700.000000   67291.901444     5  144000
# New       274945.418033  103239.582158   122  247453
# Oth       119850.000000   28441.035495     3  116050
# WD        173401.836622   71129.686245  1267  158000

# %% [markdown]
# ## SaleCondition: Condition of sale
#
#        Normal	Normal Sale
#        Abnorml	Abnormal Sale -  trade, foreclosure, short sale
#        AdjLand	Adjoining Land Purchase
#        Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage unit
#        Family	Sale between family members
#        Partial	Home was not completed when last assessed (associated with New Homes)

# %%
plot_distribution_agg('SaleCondition', dataset, 'SalePrice')
# Out:
# Missing values 0 (0.00%)
#                         mean            std   len  median
# SaleCondition
# Abnorml        146526.623762   82796.213395   101  130000
# AdjLand        104125.000000   26135.464411     4  104000
# Alloca         167377.416667   84460.527502    12  148145
# Family         149600.000000   47820.002421    20  140500
# Normal         175202.219533   69713.636280  1198  160000
# Partial        272291.752000  103696.404119   125  244600
